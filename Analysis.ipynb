# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

# %%
results = pd.read_pickle("results.pkl")

# %%
inter = results[results["Switch_type"] == "inter"]["Trials_rule2"].values

# %%
intra = results[results["Switch_type"] == "intra"]["Trials_rule2"].values

# %%
stats.levene(inter, intra)
# Out:
# LeveneResult(statistic=17.62205454921163, pvalue=3.1042110078417334e-05)

# %%
stats.ttest_ind(inter, intra)
# Out:
# Ttest_indResult(statistic=-32.46304128463078, pvalue=4.689333908222187e-134)

# %%
plt.figure(figsize=(5,6))
plt.bar(x = ["Extradimensional", "Intradimensional"],height = [np.mean(inter), np.mean(intra)], 
        width=0.5, color=["darkorange", "darkgreen"], yerr=[np.std(inter), np.std(intra)], 
        tick_label = ["Extradimensional", "Intradimensional"])
plt.ylabel("Número de ensayos", fontdict = {'fontsize': 20})
plt.title("Fase 2", fontdict = {'fontsize': 30})
plt.yticks(np.arange(0, 20, step=2), fontsize=14)
plt.xticks(fontsize=18)
plt.tight_layout()

# %%
inter_rule1 = results[results["Switch_type"] == "inter"]["Trials_rule1"].values

# %%
intra_rule1 = results[results["Switch_type"] == "intra"]["Trials_rule1"].values

# %%
stats.levene(inter_rule1, intra_rule1)
# Out:
# LeveneResult(statistic=1.8889279735400557, pvalue=0.16983771949466897)

# %%
stats.ttest_ind(inter_rule1, intra_rule1, equal_var=False)
# Out:
# Ttest_indResult(statistic=1.486816744388212, pvalue=0.1376009505355771)

# %%
plt.figure(figsize=(4,6))
plt.bar(x = ["Extradimensional", "Intradimensional"],height = [np.mean(inter_rule1), np.mean(intra_rule1)], 
        width=0.5, color=["darkorange", "darkgreen"], yerr=[np.std(inter_rule1), np.std(intra_rule1)])
plt.ylabel("Número de ensayos")
plt.title("Fase 1")
plt.tight_layout()

# %% [markdown]
# ## Hidden

# %%
results = pd.read_pickle("results-hidden.pkl")

# %%
inter = results[results["Switch_type"] == "inter"]["Trials_rule2"].values

# %%
intra = results[results["Switch_type"] == "intra"]["Trials_rule2"].values

# %%
stats.levene(inter, intra)
# Out:
# LeveneResult(statistic=12.252813603732752, pvalue=0.0007122452042319586)

# %%
stats.ttest_ind(inter, intra)
# Out:
# Ttest_indResult(statistic=-4.774347688151321, pvalue=6.609679845693169e-06)

# %%
plt.figure(figsize=(5,6))
plt.bar(x = ["Extradimensional", "Intradimensional"],height = [np.mean(inter), np.mean(intra)], 
        width=0.5, color=["darkorange", "darkgreen"], yerr=[np.std(inter), np.std(intra)], 
        tick_label = ["Extradimensional", "Intradimensional"])
plt.ylabel("Número de ensayos", fontdict = {'fontsize': 20})
plt.title("Fase 2", fontdict = {'fontsize': 30})
plt.xticks(fontsize=18)
plt.tight_layout()

# %% [markdown]
# ## Dropout distractor

# %%
results = pd.read_pickle("results-distractor.pkl")

# %%
inter = results[results["Switch_type"] == "inter"]["Trials_rule2"].values

# %%
intra = results[results["Switch_type"] == "intra"]["Trials_rule2"].values

# %%
stats.levene(inter, intra)
# Out:
# LeveneResult(statistic=11.867846532628747, pvalue=0.0006531047173524573)

# %%
stats.ttest_ind(inter, intra)
# Out:
# Ttest_indResult(statistic=-8.271381434567804, pvalue=4.45513531351148e-15)

# %%
plt.figure(figsize=(5,6))
plt.bar(x = ["Extradimensional", "Intradimensional"],height = [np.mean(inter), np.mean(intra)], 
        width=0.5, color=["darkorange", "darkgreen"], yerr=[np.std(inter), np.std(intra)], 
        tick_label = ["Extradimensional", "Intradimensional"])
plt.ylabel("Número de ensayos", fontdict = {'fontsize': 20})
plt.title("Fase 2", fontdict = {'fontsize': 30})
plt.xticks(fontsize=18)
plt.tight_layout()

# %% [markdown]
# ## Higher LR

# %%
results = pd.read_pickle("results-highLR.pkl")

# %%
inter = results[results["Switch_type"] == "inter"]["Trials_rule2"].values

# %%
intra = results[results["Switch_type"] == "intra"]["Trials_rule2"].values

# %%
intra
# Out:
# array([], dtype=object)

# %%
stats.levene(inter, intra)
# Out:
# -----------------
# ZeroDivisionErrorTraceback (most recent call last)
# <ipython-input-36-823ea8760abb> in <module>
# ----> 1 stats.levene(inter, intra)
#
# c:\anacondas\envs\tfm\lib\site-packages\scipy\stats\morestats.py in levene(*args, **kwds)
#    2318     for j in range(k):
#    2319         Ni[j] = len(args[j])
# -> 2320         Yci[j] = func(args[j])
#    2321     Ntot = np.sum(Ni, axis=0)
#    2322
#
# c:\anacondas\envs\tfm\lib\site-packages\scipy\stats\morestats.py in <lambda>(x)
#    2308
#    2309     if center == 'median':
# -> 2310         func = lambda x: np.median(x, axis=0)
#    2311     elif center == 'mean':
#    2312         func = lambda x: np.mean(x, axis=0)
#
# c:\anacondas\envs\tfm\lib\site-packages\numpy\lib\function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3495     """
#    3496     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3497                     overwrite_input=overwrite_input)
#    3498     if keepdims:
#    3499         return r.reshape(k)
#
# c:\anacondas\envs\tfm\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3403         keepdim = (1,) * a.ndim
#    3404
# -> 3405     r = func(a, **kwargs)
#    3406     return r, keepdim
#    3407
#
# c:\anacondas\envs\tfm\lib\site-packages\numpy\lib\function_base.py in _median(a, axis, out, overwrite_input)
#    3554         # Use mean in odd and even case to coerce data type
#    3555         # and check, use out array.
# -> 3556         return mean(part[indexer], axis=axis, out=out)
#    3557
#    3558
#
# c:\anacondas\envs\tfm\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3116
#    3117     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3118                           out=out, **kwargs)
#    3119
#    3120
#
# c:\anacondas\envs\tfm\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      85             ret = ret.dtype.type(ret / rcount)
#      86     else:
# ---> 87         ret = ret / rcount
#      88
#      89     return ret
#
# ZeroDivisionError: division by zero
